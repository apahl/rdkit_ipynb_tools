# %% [markdown]
# # RDKit IPython Tools Tutorial
#
# This tutorial shows some of the features of the RDKit IPython Tools. For installation of the tools, please refer to the main [README.md](../README.md).
#
# **Note:** Many features (like the notebook widgets or the JSME) are only correctly displayed when the notebook is actually run, not when it is just displayed in NBviewer. Have a look at [mol_grid](mol_grid.html) and [mol_table](mol_table.html) for example output.
#
# ## Highly Recommended Notebook Extensions ([Link](https://github.com/ipython-contrib/jupyter_contrib_nbextensions))
# 1. ExecuteTime
# 1. Freeze
# 1. Hide Input / Hide Input All
# 1. Table of Contents

# %%
# %reload_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings("ignore")

from rdkit.Chem import AllChem as Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole

try:
    Draw.DrawingOptions.atomLabelFontFace = "DejaVu Sans"
    Draw.DrawingOptions.atomLabelFontSize = 18
except KeyError:  # Font "DejaVu Sans" is not available
    pass

from rdkit_ipynb_tools import tools, pipeline as p
# Out:
# misc_tools.apl_tools                          (commit: f136688 ( 2016-09-17 19:51:28 ))
# rdkit_ipynb_tools.hc_tools                    (commit: 4a6e99b ( 2016-10-21 12:52:16 ))
# <script src="lib/highcharts.js"></script>
# <script src="lib/highcharts-more.js"></script>
# <script src="lib/modules/heatmap.js"></script>
# <script src="lib/modules/exporting.js"></script>
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f4c795fe-a820-4c51-b3bf-cabf31252224">Loading BokehJS ...</span>
#     </div>
# rdkit_ipynb_tools.tools                       (commit: 4a6e99b ( 2016-10-21 12:52:16 ))

# %% [markdown]
# ## Example Data Set
# Endothelin Receptor A (ET-A) Antagonists from [ChEMBL](https://www.ebi.ac.uk/chembl/), downloaded as tab-separated file on 31-Aug-2016, gzipped.
#
# ### Preparation
# Count the lines and display the first line

# %%
# !zcat chembl_et-a_antagonists.txt.gz | wc -l
print()
# !zcat chembl_et-a_antagonists.txt.gz | head -n 1
# Out:
# 2324
#
# CMPD_CHEMBLID	MOLREGNO	PARENT_CMPD_CHEMBLID	PARENT_MOLREGNO	MOL_PREF_NAME	COMPOUND_KEY	MOLWEIGHT	ALOGP	PSA	NUM_RO5_VIOLATIONS	CANONICAL_SMILES	ACTIVITY_ID	STANDARD_TYPE	RELATION	STANDARD_VALUE	STANDARD_UNITS	PCHEMBL_VALUE	ACTIVITY_COMMENT	DATA_VALIDITY_COMMENT	POTENTIAL_DUPLICATE	BAO_ENDPOINT	UO_UNITS	QUDT_UNITS	ASSAY_ID	ASSAY_CHEMBLID	ASSAY_TYPE	DESCRIPTION	ASSAY_SRC_ID	ASSAY_SRC_DESCRIPTION	ASSAY_ORGANISM	ASSAY_STRAIN	ASSAY_TAX_ID	CURATED_BY	BAO_FORMAT	TID	TARGET_CHEMBLID	TARGET_TYPE	PROTEIN_ACCESSION	PREF_NAME	ORGANISM	CONFIDENCE_SCORE	TARGET_MAPPING	APD_NAME	APD_CONFIDENCE	DOC_ID	DOC_CHEMBLID	PUBMED_ID	JOURNAL	YEAR	VOLUME	ISSUE	FIRST_PAGE	CELL_ID	CELL_CHEMBL_ID	CELL_NAME
#
# gzip: stdout: Broken pipe

# %% [markdown]
# We have 2323 records and a number of fields of which we will only need a few.

# %% [markdown]
# ### Curating the Data Set with Pipelines
# Pipelines are part of the tools to deal with arbitrarily large data sets with compound-awareness. This is achieved using Python generators.<br>
# We will now use a pipeline to curate the data set for our needs:
# 1. Read in the data set *(here directly as gzipped file, reading from multiple files is also possible)*
# 1. Transform the IC50 into a pIC50 *(personal pet peeve, ask me about it ;-) )*
# 1. Keep only the fields that we are interested in
# 1. Rename a field
# 1. Filter for high-activity compounds
# 1. Generate the structures from Smiles
# 1. Calculate some physicochemical properties
# 1. Finally, write everything to an SD file

# %% [markdown]
# The individual elements of the data stream are dictionaries and can be directly accessed by the `custom_man` and `custom_filter` components, using normal dict syntax (e.g. rec["&lt;field&gt;"]).<br>
# This allows a wide range of manipulations on the data stream.<br>
# Empty fields are removed from the `rec` dict, so checks for existance before use are necessary in the `custom_xxx` components.
#
# `custom_man` and `custom_filter` use `eval()` for running the code.

# %%
s = p.Summary()  # optional, used for logging what the individual components do

# code for IC50 --> pIC50 conversion
run_code = """
if "STANDARD_VALUE" in rec:
    rec["ETA_pIC50"] = tools.pic50(rec["STANDARD_VALUE"], "nM")"""  

# code for filtering high-activity compounds
run_filter = '"ETA_pIC50" in rec and rec["ETA_pIC50"] >= 8'

# define the start of the pipeline, can work directly with gzipped files
rd = p.start_csv_reader("chembl_et-a_antagonists.txt.gz", summary=s)

res = p.pipe(rd,
             (p.pipe_custom_man, run_code),
             (p.pipe_keep_props, ["CMPD_CHEMBLID", "CANONICAL_SMILES", "ETA_pIC50"]),
             (p.pipe_custom_filter, run_filter, {"summary": s}),
             (p.pipe_rename_prop, "CMPD_CHEMBLID", "Chembl_Id"),
             (p.pipe_mol_from_smiles, "CANONICAL_SMILES"),
             (p.pipe_calc_props, ["2d", "logp", "tpsa", "mw"]),
             #(p.pipe_sleep, 0.03),  # a stub comp. to slow down the pipeline for demo purposes
             # p.stop_count_records
             (p.stop_sdf_writer, "chembl_et-a_ant_active.sdf")
            )
s.update(True)
# Out:
# <table style="border: 1px solid black;"><tbody><tr><td bgcolor="#94CAEF" colspan=2><b>Pipeline finished.</b></td></tr><tr><td bgcolor="#94CAEF"><b>Component</b></td><td bgcolor="#94CAEF"><b># Records</b></td></tr><tr><td>start_csv_reader</td><td>2323</td></tr><tr><td>pipe_custom_filter</td><td>430</td></tr><tr bgcolor="#E9E9E9"><td><i>Time elapsed</i></td><td><i>00h 00m 2.12s</i></td></tr></tbody></table>

# %% [markdown]
# The progress of the pipeline is displayed in a HTML table below the cell and can also be monitored by watching the automatically created `pipeline.log` file:<br>
# Execute this in a **separate** terminal:
#
# `<workdir>$ watch -n 2 cat pipeline.log`
#
# ### Available Pipeline Components
#
# | Starting                   | Running                    | Stopping
# |----------------------------|----------------------------|---------------------------|
# | start_cache_reader         | pipe_calc_props            | stop_cache_writer         |
# | start_csv_reader           | pipe_custom_filter         | stop_count_records        |
# | start_mol_csv_reader       | pipe_custom_man            | stop_csv_writer           |
# | start_sdf_reader           | pipe_do_nothing            | stop_dict_from_stream     |
# | start_stream_from_dict     | pipe_has_prop_filter       | stop_mol_list_from_stream |
# | start_stream_from_mol_list | pipe_id_filter             | stop_sdf_writer           |
# |                            | pipe_inspect_stream        |                           |
# |                            | pipe_join_data_from_file   |                           |
# |                            | pipe_keep_largest_fragment |                           |
# |                            | pipe_keep_props            |                           |
# |                            | pipe_merge_data            |                           |
# |                            | pipe_mol_filter            |                           |
# |                            | pipe_mol_from_b64          |                           |
# |                            | pipe_mol_from_smiles       |                           |
# |                            | pipe_mol_to_b64            |                           |
# |                            | pipe_mol_to_smiles         |                           |
# |                            | pipe_neutralize_mol        |                           |
# |                            | pipe_remove_props          |                           |
# |                            | pipe_rename_prop           |                           |
# |                            | pipe_sim_filter            |                           |
# |                            | pipe_sleep                 |                           |

# %% [markdown]
# ## The Mol_List
# The main workhorse of the RDKit IPython Tools.<br>
# A literal list of molecules (molecule objects), a subclass of the trusted Python list.
#
# It can be populated by loading an SD file, from a *normal* list of molecules or as the end point of a Pipeline.

# %%
mol_list = tools.load_sdf("chembl_et-a_ant_active.sdf")
# Out:
#   > sdf chembl_et-a_ant_active loaded with 430 records.

# %% [markdown]
# Avalable methods:

# %%
print([x for x in sorted(dir(mol_list)) if not x.startswith("_")])
# Out:
# ['add_id', 'align', 'append', 'bar', 'calc_props', 'clear', 'copy', 'copy_prop', 'correlate', 'count', 'd', 'extend', 'field_types', 'fields', 'get_ids', 'grid', 'has_prop_filter', 'hist', 'ia', 'id_prop', 'index', 'insert', 'join_data_from_file', 'keep_props', 'len', 'mol_filter', 'mols_with_prop', 'nested', 'new_list_from_ids', 'order', 'order_props', 'plot_tool', 'pop', 'prop_filter', 'recalc_needed', 'remove', 'remove_dups_by_id', 'remove_dups_by_struct', 'remove_empty_props', 'remove_props', 'rename_prop', 'reverse', 'scatter', 'set_default', 'set_prop_on_mol', 'show_cpd', 'sort', 'sort_list', 'summary', 'table', 'write_grid', 'write_nested', 'write_sdf', 'write_table']

# %% [markdown]
# Please use the documentation generated by Sphinx as described in `doc/README.md` or the context help (press shift-tab in the parentheses) for reference, e.g.:<br>

# %%
# Cell is frozen, i.e. blocked from execution. 
# Very useful if you do not accidentally want to start a long-running cell again
tmp = mol_list.remove_dups_by_struct()

# %% [markdown]
# ### Overviews

# %%
mol_list.summary()
# Out:
# <table cellpadding="1" height="60px" border="1" cellspacing="1" summary="Table" align="" >
# <tbody>
# <tr><td bgcolor="#94CAEF" colspan="7" align="center" ><b>Summary (430 records)</b></td></tr>
# <tr><td bgcolor="#94CAEF" align="center" ><b>Property</b></td><td bgcolor="#94CAEF" align="center" ><b>Type</b></td><td bgcolor="#94CAEF" align="center" ><b>Num Values</b></td><td bgcolor="#94CAEF" align="center" ><b>Min</b></td><td bgcolor="#94CAEF" align="center" ><b>Max</b></td><td bgcolor="#94CAEF" align="center" ><b>Mean</b></td><td bgcolor="#94CAEF" align="center" ><b>Median</b></td></tr>
# <tr><td align="center" >ETA_pIC50</td><td align="center" >number</td><td align="center" >430</td><td align="center" >8.000</td><td align="center" >10.960</td><td align="center" >8.907</td><td align="center" >8.730</td></tr>
# <tr><td align="center" >TPSA</td><td align="center" >number</td><td align="center" >430</td><td align="center" >70.000</td><td align="center" >924.000</td><td align="center" >140.707</td><td align="center" >118.000</td></tr>
# <tr><td align="center" >Chembl_Id</td><td align="center" >str</td><td align="center" >430</td><td align="center" ></td><td align="center" ></td><td align="center" ></td><td align="center" ></td></tr>
# <tr><td align="center" >LogP</td><td align="center" >number</td><td align="center" >430</td><td align="center" >-7.860</td><td align="center" >7.520</td><td align="center" >3.987</td><td align="center" >4.200</td></tr>
# <tr><td align="center" >MW</td><td align="center" >number</td><td align="center" >430</td><td align="center" >328.390</td><td align="center" >2532.940</td><td align="center" >592.546</td><td align="center" >535.060</td></tr>
# </tbody>
# </table>

# %%
mol_list.correlate()
# Out:
# <table cellpadding="1" height="60px" border="1" cellspacing="1" summary="Table" align="" >
# <tbody>
# <tr><td bgcolor="#94CAEF" colspan="3" align="center" ><b>Property Correlation Coefficients</b></td></tr>
# <tr><td bgcolor="#94CAEF" colspan="2" align="center" ><b>A vs. B</b></td><td bgcolor="#94CAEF" align="center" ><b>Correlation</b></td></tr>
# <tr><td align="center" >TPSA</td><td align="center" >MW</td><td align="center" >0.981</td></tr>
# <tr><td align="center" >TPSA</td><td align="center" >LogP</td><td align="center" >0.739</td></tr>
# <tr><td align="center" >LogP</td><td align="center" >MW</td><td align="center" >0.669</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ### Report Tables
# #### Mol Table
# The `table` is the default view of a Mol_List and can be invoked by just calling the mol_list:

# %%
mol_list[:5]  # displays the first 5 molecules of the list
#  equivalent to:  mol_list.table()  # pagesize=5
# Out:
# [<rdkit.Chem.rdchem.Mol at 0x7fdb01bd7080>,
#  <rdkit.Chem.rdchem.Mol at 0x7fdb01bd7210>,
#  <rdkit.Chem.rdchem.Mol at 0x7fdb01bd7260>,
#  <rdkit.Chem.rdchem.Mol at 0x7fdb01bd70d0>,
#  <rdkit.Chem.rdchem.Mol at 0x7fdb01bd71c0>]

# %% [markdown]
# So, this is nice, but what if we want to see more than 5 molecules? Displaying the whole list would flood the notebook and not be very convenient.
#
# This is where the widgets of the notebook come in handy and allow a page-wise display of the molecules:

# %%
mol_list.table( pagesize=10)
# Out:
# <table cellpadding="1" height="60px" border="1" cellspacing="1" summary="Table" align="" >
# <tbody>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" ><b>#</b></td><td style="text-align: center;" bgcolor="#94CAEF" ><b>Molecule</b></td><td style="text-align: center;" bgcolor="#94CAEF" ><b>Chembl_Id</b></td><td style="text-align: center;" bgcolor="#94CAEF" ><b>ETA_pIC50</b></td><td style="text-align: center;" bgcolor="#94CAEF" ><b>LogP</b></td><td style="text-align: center;" bgcolor="#94CAEF" ><b>MW</b></td><td style="text-align: center;" bgcolor="#94CAEF" ><b>TPSA</b></td></tr>
# <tr><td id="CHEMBL287683_161021161634" >0</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL287683" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL287683</td><td style="text-align: center;" title="ETA_pIC50" >10.85</td><td style="text-align: center;" title="LogP" >4.88</td><td style="text-align: center;" title="MW" >559.66</td><td style="text-align: center;" title="TPSA" >110</td></tr>
# <tr><td id="CHEMBL293830_161021161634" >1</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL293830" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL293830</td><td style="text-align: center;" title="ETA_pIC50" >10.52</td><td style="text-align: center;" title="LogP" >4.96</td><td style="text-align: center;" title="MW" >493.99</td><td style="text-align: center;" title="TPSA" >118</td></tr>
# <tr><td id="CHEMBL286621_161021161634" >2</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL286621" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL286621</td><td style="text-align: center;" title="ETA_pIC50" >10.32</td><td style="text-align: center;" title="LogP" >3.51</td><td style="text-align: center;" title="MW" >520.58</td><td style="text-align: center;" title="TPSA" >130</td></tr>
# <tr><td id="CHEMBL419367_161021161634" >3</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL419367" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL419367</td><td style="text-align: center;" title="ETA_pIC50" >10.26</td><td style="text-align: center;" title="LogP" >4.79</td><td style="text-align: center;" title="MW" >618.65</td><td style="text-align: center;" title="TPSA" >105</td></tr>
# <tr><td id="CHEMBL289216_161021161634" >4</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL289216" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL289216</td><td style="text-align: center;" title="ETA_pIC50" >10.24</td><td style="text-align: center;" title="LogP" >4.38</td><td style="text-align: center;" title="MW" >520.58</td><td style="text-align: center;" title="TPSA" >119</td></tr>
# <tr><td id="CHEMBL62112_161021161634" >5</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL62112" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL62112</td><td style="text-align: center;" title="ETA_pIC50" >10.22</td><td style="text-align: center;" title="LogP" >4.96</td><td style="text-align: center;" title="MW" >481.98</td><td style="text-align: center;" title="TPSA" >118</td></tr>
# <tr><td id="CHEMBL37920_161021161634" >6</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL37920" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL37920</td><td style="text-align: center;" title="ETA_pIC50" >10.19</td><td style="text-align: center;" title="LogP" >5.32</td><td style="text-align: center;" title="MW" >532.64</td><td style="text-align: center;" title="TPSA" >110</td></tr>
# <tr><td id="CHEMBL432521_161021161634" >7</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL432521" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL432521</td><td style="text-align: center;" title="ETA_pIC50" >10.1</td><td style="text-align: center;" title="LogP" >4.23</td><td style="text-align: center;" title="MW" >447.54</td><td style="text-align: center;" title="TPSA" >118</td></tr>
# <tr><td id="CHEMBL58359_161021161634" >8</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL58359" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL58359</td><td style="text-align: center;" title="ETA_pIC50" >10.1</td><td style="text-align: center;" title="LogP" >4.20</td><td style="text-align: center;" title="MW" >444.54</td><td style="text-align: center;" title="TPSA" >125</td></tr>
# <tr><td id="CHEMBL293398_161021161634" >9</td><td><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL293398" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" title="Chembl_Id" >CHEMBL293398</td><td style="text-align: center;" title="ETA_pIC50" >10.05</td><td style="text-align: center;" title="LogP" >5.02</td><td style="text-align: center;" title="MW" >460.36</td><td style="text-align: center;" title="TPSA" >101</td></tr>
# </tbody>
# </table>

# %% [markdown]
# #### Nested Mol Table
# The nested mol table displays the properties next to the structure:

# %%
mol_list.nested()  # pagesize=5
# Out:
# <table cellpadding="1" height="60px" border="1" cellspacing="1" summary="Table" align="" >
# <tbody>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" ><b>Molecule</b></td><td style="text-align: center;" bgcolor="#94CAEF" colspan="2" ><b>Properties</b></td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL287683" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#FFFFFF" >Chembl_Id</td><td bgcolor="#FFFFFF" >CHEMBL287683</td></tr>
# <tr><td bgcolor="#FFFFFF" >ETA_pIC50</td><td bgcolor="#FFFFFF" >10.85</td></tr>
# <tr><td bgcolor="#FFFFFF" >LogP</td><td bgcolor="#FFFFFF" >4.88</td></tr>
# <tr><td bgcolor="#FFFFFF" >MW</td><td bgcolor="#FFFFFF" >559.66</td></tr>
# <tr><td bgcolor="#FFFFFF" >TPSA</td><td bgcolor="#FFFFFF" >110</td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL293830" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#F2F2F2" >Chembl_Id</td><td bgcolor="#F2F2F2" >CHEMBL293830</td></tr>
# <tr><td bgcolor="#F2F2F2" >ETA_pIC50</td><td bgcolor="#F2F2F2" >10.52</td></tr>
# <tr><td bgcolor="#F2F2F2" >LogP</td><td bgcolor="#F2F2F2" >4.96</td></tr>
# <tr><td bgcolor="#F2F2F2" >MW</td><td bgcolor="#F2F2F2" >493.99</td></tr>
# <tr><td bgcolor="#F2F2F2" >TPSA</td><td bgcolor="#F2F2F2" >118</td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL286621" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#FFFFFF" >Chembl_Id</td><td bgcolor="#FFFFFF" >CHEMBL286621</td></tr>
# <tr><td bgcolor="#FFFFFF" >ETA_pIC50</td><td bgcolor="#FFFFFF" >10.32</td></tr>
# <tr><td bgcolor="#FFFFFF" >LogP</td><td bgcolor="#FFFFFF" >3.51</td></tr>
# <tr><td bgcolor="#FFFFFF" >MW</td><td bgcolor="#FFFFFF" >520.58</td></tr>
# <tr><td bgcolor="#FFFFFF" >TPSA</td><td bgcolor="#FFFFFF" >130</td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL419367" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#F2F2F2" >Chembl_Id</td><td bgcolor="#F2F2F2" >CHEMBL419367</td></tr>
# <tr><td bgcolor="#F2F2F2" >ETA_pIC50</td><td bgcolor="#F2F2F2" >10.26</td></tr>
# <tr><td bgcolor="#F2F2F2" >LogP</td><td bgcolor="#F2F2F2" >4.79</td></tr>
# <tr><td bgcolor="#F2F2F2" >MW</td><td bgcolor="#F2F2F2" >618.65</td></tr>
# <tr><td bgcolor="#F2F2F2" >TPSA</td><td bgcolor="#F2F2F2" >105</td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL289216" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#FFFFFF" >Chembl_Id</td><td bgcolor="#FFFFFF" >CHEMBL289216</td></tr>
# <tr><td bgcolor="#FFFFFF" >ETA_pIC50</td><td bgcolor="#FFFFFF" >10.24</td></tr>
# <tr><td bgcolor="#FFFFFF" >LogP</td><td bgcolor="#FFFFFF" >4.38</td></tr>
# <tr><td bgcolor="#FFFFFF" >MW</td><td bgcolor="#FFFFFF" >520.58</td></tr>
# <tr><td bgcolor="#FFFFFF" >TPSA</td><td bgcolor="#FFFFFF" >119</td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL62112" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#F2F2F2" >Chembl_Id</td><td bgcolor="#F2F2F2" >CHEMBL62112</td></tr>
# <tr><td bgcolor="#F2F2F2" >ETA_pIC50</td><td bgcolor="#F2F2F2" >10.22</td></tr>
# <tr><td bgcolor="#F2F2F2" >LogP</td><td bgcolor="#F2F2F2" >4.96</td></tr>
# <tr><td bgcolor="#F2F2F2" >MW</td><td bgcolor="#F2F2F2" >481.98</td></tr>
# <tr><td bgcolor="#F2F2F2" >TPSA</td><td bgcolor="#F2F2F2" >118</td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL37920" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#FFFFFF" >Chembl_Id</td><td bgcolor="#FFFFFF" >CHEMBL37920</td></tr>
# <tr><td bgcolor="#FFFFFF" >ETA_pIC50</td><td bgcolor="#FFFFFF" >10.19</td></tr>
# <tr><td bgcolor="#FFFFFF" >LogP</td><td bgcolor="#FFFFFF" >5.32</td></tr>
# <tr><td bgcolor="#FFFFFF" >MW</td><td bgcolor="#FFFFFF" >532.64</td></tr>
# <tr><td bgcolor="#FFFFFF" >TPSA</td><td bgcolor="#FFFFFF" >110</td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL432521" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#F2F2F2" >Chembl_Id</td><td bgcolor="#F2F2F2" >CHEMBL432521</td></tr>
# <tr><td bgcolor="#F2F2F2" >ETA_pIC50</td><td bgcolor="#F2F2F2" >10.1</td></tr>
# <tr><td bgcolor="#F2F2F2" >LogP</td><td bgcolor="#F2F2F2" >4.23</td></tr>
# <tr><td bgcolor="#F2F2F2" >MW</td><td bgcolor="#F2F2F2" >447.54</td></tr>
# <tr><td bgcolor="#F2F2F2" >TPSA</td><td bgcolor="#F2F2F2" >118</td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL58359" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#FFFFFF" >Chembl_Id</td><td bgcolor="#FFFFFF" >CHEMBL58359</td></tr>
# <tr><td bgcolor="#FFFFFF" >ETA_pIC50</td><td bgcolor="#FFFFFF" >10.1</td></tr>
# <tr><td bgcolor="#FFFFFF" >LogP</td><td bgcolor="#FFFFFF" >4.20</td></tr>
# <tr><td bgcolor="#FFFFFF" >MW</td><td bgcolor="#FFFFFF" >444.54</td></tr>
# <tr><td bgcolor="#FFFFFF" >TPSA</td><td bgcolor="#FFFFFF" >125</td></tr>
# <tr><td rowspan="5" align="center" ><img  style="max-width: 300px; max-height: 300px; display: block; margin: auto;" title="CHEMBL293398" src="data:image/png;base64,..." alt="icon" /></td><td bgcolor="#F2F2F2" >Chembl_Id</td><td bgcolor="#F2F2F2" >CHEMBL293398</td></tr>
# <tr><td bgcolor="#F2F2F2" >ETA_pIC50</td><td bgcolor="#F2F2F2" >10.05</td></tr>
# <tr><td bgcolor="#F2F2F2" >LogP</td><td bgcolor="#F2F2F2" >5.02</td></tr>
# <tr><td bgcolor="#F2F2F2" >MW</td><td bgcolor="#F2F2F2" >460.36</td></tr>
# <tr><td bgcolor="#F2F2F2" >TPSA</td><td bgcolor="#F2F2F2" >101</td></tr>
# </tbody>
# </table>

# %% [markdown]
# #### Grid Table
# The grid table displays the molecules in a grid. You can pass additional property names to be shown below the structures (separated by "\_"):

# %%
mol_list.grid()  # props="ETA_pIC50"   props=["ETA_pIC50", "TPSA"]
# Out:
# <table cellpadding="1" height="60px" border="1" cellspacing="1" summary="Table" align="" >
# <tbody>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL287683_161021161635" >CHEMBL287683</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL293830_161021161635" >CHEMBL293830</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL286621_161021161635" >CHEMBL286621</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL419367_161021161635" >CHEMBL419367</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL287683" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL293830" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL286621" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL419367" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL289216_161021161635" >CHEMBL289216</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL62112_161021161635" >CHEMBL62112</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL37920_161021161635" >CHEMBL37920</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL432521_161021161635" >CHEMBL432521</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL289216" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL62112" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL37920" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL432521" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL58359_161021161635" >CHEMBL58359</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL293398_161021161635" >CHEMBL293398</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL305602_161021161635" >CHEMBL305602</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL437472_161021161635" >CHEMBL437472</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL58359" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL293398" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL305602" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL437472" src="data:image/png;base64,..." alt="icon" /></td></tr>
# </tbody>
# </table>

# %% [markdown]
# ### Data Manipulation and Filtering
# **Note:** Mol_List methods that change the length of the list (e.g. filters) return a *new* Mol_List instance (by default an independent copy).
# Methods that do not change the length (e.g. calculating data or renaming fields) modify the list *in-place*.

# %% [markdown]
# #### Filter by a Property
# * By default, the resulting Mol_List is reversely sorted on the filtered property, if it is numeric
# * Text searches are always lower-case!

# %%
lipophilic = mol_list.prop_filter('LogP >= 5')
# Out:
#   > field LogP extracted from query: LogP >= 5.
#   > processed:     430   found:     88

# %%
lipophilic.grid(props="LogP")
# Out:
# <table cellpadding="1" height="60px" border="1" cellspacing="1" summary="Table" align="" >
# <tbody>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL2058376_161021161635" >CHEMBL2058376</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL322920_161021161635" >CHEMBL322920</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL322920_161021161635" >CHEMBL322920</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL322920_161021161635" >CHEMBL322920</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL2058376" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL322920" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL322920" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL322920" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td align="center" >7.52</td><td align="center" >7.50</td><td align="center" >7.50</td><td align="center" >7.50</td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL2058374_161021161635" >CHEMBL2058374</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL2058373_161021161635" >CHEMBL2058373</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL268201_161021161635" >CHEMBL268201</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL2058371_161021161635" >CHEMBL2058371</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL2058374" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL2058373" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL268201" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL2058371" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td align="center" >7.26</td><td align="center" >7.15</td><td align="center" >6.95</td><td align="center" >6.81</td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL2058375_161021161635" >CHEMBL2058375</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL71070_161021161635" >CHEMBL71070</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL2058372_161021161635" >CHEMBL2058372</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL2058370_161021161635" >CHEMBL2058370</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL2058375" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL71070" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL2058372" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL2058370" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td align="center" >6.64</td><td align="center" >6.52</td><td align="center" >6.51</td><td align="center" >6.50</td></tr>
# </tbody>
# </table>
# <p>properties shown: [LogP]</p>

# %% [markdown]
# Sort by pIC50 and keep only the 100 most active:
# * Sorting is reverse by default!
# * Slicing a Mol_List creates a new Mol_List instance.

# %%
mol_list.sort_list("ETA_pIC50")  # reverse by default!
most_act = mol_list[:100]  # slicing a Mol_List creates a new Mol_List instance.

most_act.grid(props="ETA_pIC50")
# Out:
# <table cellpadding="1" height="60px" border="1" cellspacing="1" summary="Table" align="" >
# <tbody>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL411925_161021161636" >CHEMBL411925</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL286621_161021161636" >CHEMBL286621</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL289634_161021161636" >CHEMBL289634</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL287683_161021161636" >CHEMBL287683</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL411925" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL286621" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL289634" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL287683" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td align="center" >10.96</td><td align="center" >10.96</td><td align="center" >10.96</td><td align="center" >10.85</td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL432856_161021161636" >CHEMBL432856</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL294291_161021161636" >CHEMBL294291</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL60058_161021161636" >CHEMBL60058</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL35984_161021161636" >CHEMBL35984</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL432856" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL294291" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL60058" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL35984" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td align="center" >10.85</td><td align="center" >10.7</td><td align="center" >10.7</td><td align="center" >10.66</td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL287683_161021161636" >CHEMBL287683</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL289634_161021161636" >CHEMBL289634</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL37427_161021161636" >CHEMBL37427</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL293830_161021161636" >CHEMBL293830</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL287683" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL289634" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL37427" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL293830" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td align="center" >10.62</td><td align="center" >10.6</td><td align="center" >10.57</td><td align="center" >10.52</td></tr>
# </tbody>
# </table>
# <p>properties shown: [ETA_pIC50]</p>

# %% [markdown]
# #### Filter by Substructure

# %%
smi = "c2ccc(c1ccccc1)cc2"
biphenyl = mol_list.mol_filter(smi)
# Out:
# > processed:     430   found:     28

# %%
biphenyl.grid()
# Out:
# <table cellpadding="1" height="60px" border="1" cellspacing="1" summary="Table" align="" >
# <tbody>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL32066_161021161636" >CHEMBL32066</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL282187_161021161636" >CHEMBL282187</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL31544_161021161636" >CHEMBL31544</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL31763_161021161636" >CHEMBL31763</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL32066" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL282187" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL31544" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL31763" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL238539_161021161636" >CHEMBL238539</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL286014_161021161636" >CHEMBL286014</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL285976_161021161636" >CHEMBL285976</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL32572_161021161636" >CHEMBL32572</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL238539" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL286014" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL285976" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL32572" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL80857_161021161636" >CHEMBL80857</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL58058_161021161636" >CHEMBL58058</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL241460_161021161636" >CHEMBL241460</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL31592_161021161636" >CHEMBL31592</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL80857" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL58058" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL241460" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL31592" src="data:image/png;base64,..." alt="icon" /></td></tr>
# </tbody>
# </table>

# %% [markdown]
# But where does the Smiles come from?
#
# Wouldn't it be nice, if we could actually draw the structure we want to search in the notebook?<br>
# Introducing...
#
# #### The Javascript Molecule Editor ([JSME](http://peter-ertl.com/jsme/), &#169; Peter Ertl) INSIDE the Jupyter Notebook
# (**note:** the JSME widget is only displayed when you actually run the cell, not when you just view the notebook, e.g. in NBViewer. Also, the state of the editor is not saved, so for documentation purposes, the drawn molecule should be displayed in the notebook afterwards.)
#
# When clicking `done`, a global RDKit mol object becomes available, which can be further processed. Other names for the mol object can be used by passing them as string to the jsme() function.

# %%
tools.jsme()
# Out:
# <script type="text/javascript" src="lib/jsme/jsme.nocache.js"></script>
# <script type="text/javascript">
#
# function jsmeOnLoad() {
#     //arguments: HTML id, width, height (must be string not number!)
#     jsmeApplet161021161636 = new JSApplet.JSME("appletContainer161021161636", "380px", "340px", {
#                      //optional parameters
#                      "options" : "query,hydrogens"
#     });
# }
#
# function onSubmit() {
#     var drawing = jsmeApplet161021161636.molFile();
#     // document.getElementById('jsme_smiles161021161636').value = drawing;
#     var command = 'mol = Chem.MolFromMolBlock("""' + drawing + '""")';
#     console.log("Executing Command: " + command);
#
#     var kernel = IPython.notebook.kernel;
#     kernel.execute(command);
# }
# </script>
#
# <table align="left" style="border: none;">
# <tr style="border: none;">
# <td id="appletContainer161021161636" style="border: none;"></td>
# <td style="vertical-align: bottom; border: none;">
# <button onclick="onSubmit()">done !</button>
# </td>
# </tr>
# </table>

# %%
smi = Chem.MolToSmiles(mol)
smi
# Out:
# 'c1ccc(-c2ccccc2)cc1'

# %%
biphenyl = mol_list.mol_filter(mol)  # use mol or smi here; by default, the result is aligned (can be turned off).
biphenyl.grid()
# Out:
# <table cellpadding="1" height="60px" border="1" cellspacing="1" summary="Table" align="" >
# <tbody>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL32066_161021161712" >CHEMBL32066</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL282187_161021161712" >CHEMBL282187</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL31544_161021161712" >CHEMBL31544</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL31763_161021161712" >CHEMBL31763</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL32066" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL282187" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL31544" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL31763" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL238539_161021161712" >CHEMBL238539</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL286014_161021161712" >CHEMBL286014</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL285976_161021161712" >CHEMBL285976</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL32572_161021161712" >CHEMBL32572</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL238539" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL286014" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL285976" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL32572" src="data:image/png;base64,..." alt="icon" /></td></tr>
# <tr><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL80857_161021161712" >CHEMBL80857</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL58058_161021161712" >CHEMBL58058</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL241460_161021161712" >CHEMBL241460</td><td style="text-align: center;" bgcolor="#94CAEF" id="CHEMBL31592_161021161712" >CHEMBL31592</td></tr>
# <tr><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL80857" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL58058" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL241460" src="data:image/png;base64,..." alt="icon" /></td><td style="text-align: center;" ><img  style="max-width: 235px; max-height: 235px; display: block; margin: auto;" title="CHEMBL31592" src="data:image/png;base64,..." alt="icon" /></td></tr>
# </tbody>
# </table>

# %% [markdown]
# #### Report Writers
# All the reports shown here can also be written to file in HTML format, just use the mol_list.write_xxx() method instead.
#
# When the Mol_List is set to **interactive**, the compounds in the report become **selectable** (not implemented for nested_table)!

# %%
biphenyl.ia = True  # setting biphenyl to interactive
biphenyl.write_grid(props=["ETA_pIC50", "TPSA"])
#biphenyl.write_table()
# Out:
# <a href="mol_grid.html">mol_grid.html</a>

# %% [markdown]
# ### Plotting
# Using Highcharts or Bokeh. Bokeh is preferred and is actively developed.<br>
# The plots are interactive (can be panned, zoomed) and contain structure tooltips!! &nbsp;&nbsp;&nbsp; \o/
#
# The plotting functionality can also be used on its own with dictionaries or Pandas objects as input.

# %%
biphenyl.scatter("LogP", "ETA_pIC50")
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="bbe3c8ea-b2b0-4c8b-9793-b713e10f0a5d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#bbe3c8ea-b2b0-4c8b-9793-b713e10f0a5d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bbe3c8ea-b2b0-4c8b-9793-b713e10f0a5d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bbe3c8ea-b2b0-4c8b-9793-b713e10f0a5d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5ebbc498-8f92-486d-b200-e740e8f1eacb":{"roots":{"references":[{"attributes":{"callback":null},"id":"001b281b-7152-4501-9c7d-3d5b7ed3f0be","type":"DataRange1d"},{"attributes":{"plot":{"id":"5c35c726-2903-4788-8846-510bbde2a5e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"f2238814-6f74-40a9-aff7-f418fbc93f63","type":"BasicTicker"}},"id":"884fd58f-4be9-4c47-a370-5997c86168e2","type":"Grid"},{"attributes":{"plot":{"id":"5c35c726-2903-4788-8846-510bbde2a5e1","subtype":"Figure","type":"Plot"}},"id":"38c1c0db-7b8f-47a0-9337-3681c08ece44","type":"SaveTool"},{"attributes":{"axis_label":"LogP","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"dd008b70-351a-4a55-b233-95be180ec201","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"14pt"},"plot":{"id":"5c35c726-2903-4788-8846-510bbde2a5e1","subtype":"Figure","type":"Plot"},"ticker":{"id":"f2238814-6f74-40a9-aff7-f418fbc93f63","type":"BasicTicker"}},"id":"15b63101-4f0f-4a98-97ea-f91f670004c7","type":"LinearAxis"},{"attributes":{"below":[{"id":"15b63101-4f0f-4a98-97ea-f91f670004c7","type":"LinearAxis"}],"left":[{"id":"29149ca2-c127-4d8b-a07c-42b05b4606ea","type":"LinearAxis"}],"plot_height":450,"renderers":[{"id":"15b63101-4f0f-4a98-97ea-f91f670004c7","type":"LinearAxis"},{"id":"884fd58f-4be9-4c47-a370-5997c86168e2","type":"Grid"},{"id":"29149ca2-c127-4d8b-a07c-42b05b4606ea","type":"LinearAxis"},{"id":"65092a77-6f1c-4733-9e89-00c1afda4d69","type":"Grid"},{"id":"103c9968-5494-4adb-9897-1843246293b3","type":"BoxAnnotation"},{"id":"705486b8-335e-4b76-be4f-4c6145f7e34b","type":"GlyphRenderer"}],"title":{"id":"b17827f4-8ae9-424e-bd03-de969e97c0fd","type":"Title"},"tool_events":{"id":"51423aaa-c6f2-4acf-a0ea-966ce08bc53c","type":"ToolEvents"},"toolbar":{"id":"e7b31812-98b0-43a9-abbf-236b665460b6","type":"Toolbar"},"x_range":{"id":"001b281b-7152-4501-9c7d-3d5b7ed3f0be","type":"DataRange1d"},"y_range":{"id":"2330cd9e-3241-4e36-a658-cb50b03384e0","type":"DataRange1d"}},"id":"5c35c726-2903-4788-8846-510bbde2a5e1","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["y","TPSA","Chembl_Id","mol","ETA_pIC50","x","LogP","MW"],"data":{"Chembl_Id":["CHEMBL32066","CHEMBL282187","CHEMBL31544","CHEMBL31763","CHEMBL238539","CHEMBL286014","CHEMBL285976","CHEMBL32572","CHEMBL80857","CHEMBL58058","CHEMBL241460","CHEMBL31592","CHEMBL31324","CHEMBL316453","CHEMBL310739","CHEMBL32075","CHEMBL268201","CHEMBL429019","CHEMBL398070","CHEMBL319754","CHEMBL310427","CHEMBL2058372","CHEMBL2058371","CHEMBL2058373","CHEMBL2058370","CHEMBL2058374","CHEMBL2058376","CHEMBL2058375"],"ETA_pIC50":[9.3,9.3,9.2,9.1,9.0,9.0,9.0,8.9,8.85,8.83,8.8,8.8,8.6,8.52,8.42,8.4,8.34,8.11,8.1,8.1,8.08,8.05,8.03,8.02,8.01,8.01,8.0,8.0],"LogP":[3.82,3.84,3.18,4.01,5.19,4.62,3.56,4.27,4.21,6.03,5.33,4.29,4.16,5.68,4.1,4.64,6.95,5.73,5.77,6.09,3.76,6.51,6.81,7.15,6.5,7.26,7.52,6.64],"MW":[468.58,512.63,498.61,519.42,508.6,547.48,454.55,533.45,393.26,502.02,859.95,577.5,482.61,614.7,348.81,533.45,980.11,1267.46,1006.14,638.65,328.39,544.68,528.68,549.1,514.65,593.55,582.65,532.64],"TPSA":[110,119,130,124,118,101,124,110,72,101,218,119,101,113,72,110,227,312,246,104,72,99,90,90,90,90,90,90],"mol":["...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","...","..."],"x":[3.82,3.84,3.18,4.01,5.19,4.62,3.56,4.27,4.21,6.03,5.33,4.29,4.16,5.68,4.1,4.64,6.95,5.73,5.77,6.09,3.76,6.51,6.81,7.15,6.5,7.26,7.52,6.64],"y":[9.3,9.3,9.2,9.1,9.0,9.0,9.0,8.9,8.85,8.83,8.8,8.8,8.6,8.52,8.42,8.4,8.34,8.11,8.1,8.1,8.08,8.05,8.03,8.02,8.01,8.01,8.0,8.0]}},"id":"c1e778a0-f5f6-4c43-9904-f5c3c4787d18","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"2330cd9e-3241-4e36-a658-cb50b03384e0","type":"DataRange1d"},{"attributes":{},"id":"f2238814-6f74-40a9-aff7-f418fbc93f63","type":"BasicTicker"},{"attributes":{"axis_label":"ETA_pIC50","axis_label_text_font_size":{"value":"1 ...

# %%
biphenyl.hist("ETA_pIC50")
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="58c2865d-7f40-4293-8274-15158c14dc32"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#58c2865d-7f40-4293-8274-15158c14dc32").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("58c2865d-7f40-4293-8274-15158c14dc32");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '58c2865d-7f40-4293-8274-15158c14dc32' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"905daa37-702e-4535-94fa-17ace44e07ae":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"d2ae6d82-ff9e-4cc4-be9c-34df1ef9125f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4f45be58-3386-42a2-a380-ec7faa6627a2","type":"BasicTicker"}},"id":"66e101ad-64b0-45a4-aa39-b696e689ce51","type":"Grid"},{"attributes":{"plot":{"id":"d2ae6d82-ff9e-4cc4-be9c-34df1ef9125f","subtype":"Figure","type":"Plot"},"ticker":{"id":"673ed4f7-cfab-493e-9853-a518c673b138","type":"BasicTicker"}},"id":"89830161-5304-4737-b3d3-eaa059027bdb","type":"Grid"},{"attributes":{"callback":null},"id":"ad6cf9a8-6c5c-4483-8489-bd9c0b4f0593","type":"DataRange1d"},{"attributes":{"callback":null},"id":"dd023b18-0b96-412c-9e72-b4c60bb08a27","type":"DataRange1d"},{"attributes":{},"id":"7850dc53-8616-44ab-bdf0-46914f314c42","type":"ToolEvents"},{"attributes":{"data_source":{"id":"d29ee411-e23f-4e4d-a2b7-e128b514913f","type":"ColumnDataSource"},"glyph":{"id":"1e91a8a5-681a-4d67-9302-e5765ea26616","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"2bf8d627-aa64-4aa5-8dc0-dd9523c4c844","type":"Quad"},"selection_glyph":null},"id":"cf2ea1cb-e4ec-480d-8e88-a365c8da5e8d","type":"GlyphRenderer"},{"attributes":{"axis_label":"ETA_pIC50","formatter":{"id":"2c954113-8161-4f89-a13f-81b4992077cc","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"14pt"},"plot":{"id":"d2ae6d82-ff9e-4cc4-be9c-34df1ef9125f","subtype":"Figure","type":"Plot"},"ticker":{"id":"673ed4f7-cfab-493e-9853-a518c673b138","type":"BasicTicker"}},"id":"28e4bc18-141b-42bc-ab7d-fe0d2f358fa2","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":[8.0,8.13,8.26,8.39,8.52,8.65,8.780000000000001,8.91,9.040000000000001,9.17],"right":[8.13,8.26,8.39,8.52,8.65,8.780000000000001,8.91,9.040000000000001,9.17,9.3],"top":[11,0,1,2,2,0,5,3,1,3]}},"id":"d29ee411-e23f-4e4d-a2b7-e128b514913f","type":"ColumnDataSource"},{"attributes":{},"id":"730f3349-4a4a-4004-bffd-677f3b44d026","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d2ae6d82-ff9e-4cc4-be9c-34df1ef9125f","subtype":"Figure","type":"Plot"}},"id":"8fd941a4-d4a3-4c7f-8465-b733badfc4d0","type":"WheelZoomTool"},{"attributes":{},"id":"2c954113-8161-4f89-a13f-81b4992077cc","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Distribution"},"id":"43714891-5d0c-48dc-8f59-dda0434ce3e9","type":"Title"},{"attributes":{"overlay":{"id":"bc12fdac-3f53-48eb-967c-62e4d6471905","type":"BoxAnnotation"},"plot":{"id":"d2ae6d82-ff9e-4cc4-be9c-34df1ef9125f","subtype":"Figure","type":"Plot"}},"id":"8f3c2f41-18d8-47d3-8306-4cc289cdceb0","type":"BoxZoomTool"},{"attributes":{},"id":"673ed4f7-cfab-493e-9853-a518c673b138","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bc12fdac-3f53-48eb-967c-62e4d6471905","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"d2ae6d82-ff9e-4cc4-be9c-34df1ef9125f","subtype":"Figure","type":"Plot"}},"id":"127ccd07-a1b8-4f36-8aa6-56cc564503fd","type":"SaveTool"},{"attributes":{"plot":{"id":"d2ae6d82-ff9e-4cc4-be9c-34df1ef9125f","subtype":"Figure","type":"Plot"}},"id":"075c7bda-43ab-4047-8793-7d77463fda46","type":"HelpTool"},{"attributes":{"plot":{"id":"d2ae6d82-ff9e-4cc4-be9c-34df1ef9125f","subtype":"Figure","type":"Plot"}},"id":"1cca8463-5b9d-4709-b683-547385ed5cfa","type":"PanTool"},{"attributes":{"below":[{"id":"28e4bc18-141b-42bc-ab7d-fe0d2f358fa2","type":"LinearAxis"}],"left":[{"id":"0d5ef9b7-cf54-4d16-9c4b-127ed538853b","type":"LinearAxis"}],"renderers":[{"id":"28e4bc18-141b-42bc-ab7d-fe0d2f358fa2","type":"LinearAxis"},{"id":"89830161-5304-4737-b3d3-eaa059027bdb","type":"Grid"},{"id":"0d5ef9b7-cf54-4d16-9c4b-127ed538853b","type":"Line ...

# %% [markdown]
# ### What Else?

# %% [markdown]
# #### Methods
# * Calculate properties (2d, date, formula, smiles, hba, hbd, logp, molid, mw, rotb, sa (synthetic accessibility), tpsa)
# * Generate a new Mol_List from a list of Ids
# * Remove duplicates by Id or by structure
# * Keep / remove properties
# * Add default properties
#
# #### Properties
# * `order (list[str])`: define the order (as list of property names), in which the properties are displayed in the HTML reports
#   * e.g.: `mol_list.order = ["Compound_Id", "ETA_pIC50", "LogP"]`
#   * the list does not have to be complete, the other properties follow after the ordered ones
# * `id_prop (str)`: define the name of the property used for identifying molecules
# (by default, a property ending with "id" (case-insensitive) is taken)
# * `ia (bool)`: set the interactivity of the Mol_List, see above

# %% [markdown]
# # Tips & Tricks
# ## Pipelines, Structures and Performance
# Processing data from 200k compounds takes 10-15 sec on my notebook.
#
# Substructure searches take longer.
#
# For performance reasons, I use b64encode and pickle strings of mol objects to store the molecule structures in text format<br>
# (see also Greg's blog post for [faster structure generation](http://rdkit.blogspot.de/2016/09/avoiding-unnecessary-work-and.html)):
#
# ```python
# b64encode(pickle.dumps(mol)).decode()
# ```
# For me, that has proven to be the fastest method when dealing with flat text files and is also the reason why there are `pipe_mol_to_b64` and `pipe_mol_from_b64` components in the `pipeline` module.
#
# ## Working Offline
# * When you use a local copy of the Javascript Molecule Editor as described in the README.md
# and use Bokeh for plotting, you can work completely offline in your Notebook.
#
# # Roadmap
# * make pipelines more user-friendly
# * complete the scaffolds module
# * add functionality as needed / requested
#
# (probably not in this order)
